# %%
import numpy as np
e=np.arange(0,30,5)
print(e)
# Out:
# [ 0  5 10 15 20 25]

# %%
arr=np.array([[1,2,3,4],[5,2,4,2],[1,2,0,1]])
newarr=arr.reshape(4,3)
print("\nOriginal array:\n",arr)
print("Reshape array[4,3]:\n",newarr)
# Out:
# Original array:
#  [[1 2 3 4]
#  [5 2 4 2]
#  [1 2 0 1]]
# Reshape array[4,3]:
#  [[1 2 3]
#  [4 5 2]
#  [4 2 1]
#  [2 0 1]]
