# %% [markdown]
# <a href="https://colab.research.google.com/github/shumrutha/240901104-python/blob/main/240901104_Textfile%20and%20JSON%20operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#open a text file in 'write' mode to write given lines
f=open("textfile.txt",'w')
f.write("first line\n")
f.write("Second line\n")
f.write("third line\n")
f.close()
#open a text file in'read' mode to read and print the available lines-readline function
k=open("textfile.txt",'r')
print(k.readline())
print(k.readline())
print(k.readline())
k.close()
# Out:
# first line
#
# Second line
#
# third line

# %%
#open a txt file in 'append'mode to add/append a new line inputs
m=open("textfile.txt",'a')
m.write("fourth line\n")
m.write("fifthline\n")
m.close()
#open a text file in 'read mode to read and print the available full text- read function
p=open("textfile.txt",'r')
print(p.read())
p.close()
# Out:
# first line
# Second line
# third line
# fourth line
# fifthline

# %%
import json
#json string
x='{"name":"John","age":30,"city":"New York"}'
#convert JSON string to python dictionary
y=json.loads(x)
print(y["age"])
# Out:
# 30

# %%
with open("textfile.txt",'r') as file:
  lines=file.readlines()
  print(lines)
# Out:
# ['first line\n', 'Second line\n', 'third line\n', 'fourth line\n', 'fifthline\n']

# %%
#python dictionary
data={
    "name":"john",
    "age":30,
    "city":"New York"

}
#Convert python dictionary to JSON string
json_data=json.dumps(data)
print(json_data)
# Out:
# {"name": "john", "age": 30, "city": "New York"}
