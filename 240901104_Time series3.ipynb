# %% [markdown]
# <a href="https://colab.research.google.com/github/shumrutha/240901104-python/blob/main/240901104_Time%20series3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime

#create a date variable that contains the dates
dates = [datetime(2011, 1, 2),
datetime(2011, 1, 5),
datetime(2011, 1, 7),
datetime(2011, 1, 8),
datetime(2011, 1, 10),
datetime(2011, 1, 12)]

#with this date object, create a series
ts = pd.Series(np.random.randn(6), index=dates)
print("Date Index \n",ts)
# Out:
# Date Index
#  2011-01-02   -0.574342
# 2011-01-05   -0.784069
# 2011-01-07    1.430125
# 2011-01-08   -0.461027
# 2011-01-10    0.325608
# 2011-01-12    0.759002
# dtype: float64

# %%
print("\nDate Index alone from the series: \n",ts.index)
# Out:
# Date Index alone from the series:
#  DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
stamp=ts.index[2]
print("\nSecond index:\n", stamp)
# Out:
# Second index:
#  2011-01-07 00:00:00

# %%
#play like a ball with long-times series
longer_ts=pd.Series(np.random.randn(1000),
index=pd.date_range("2000-01-01",periods=1000))
print("\nDaterange up to 1000 days:\n",longer_ts)
# Out:
# Daterange up to 1000 days:
#  2000-01-01    0.589928
# 2000-01-02   -0.657529
# 2000-01-03   -0.867016
# 2000-01-04    1.346221
# 2000-01-05    0.003113
#                 ...
# 2002-09-22   -2.013063
# 2002-09-23    0.833201
# 2002-09-24    0.966244
# 2002-09-25    0.394445
# 2002-09-26   -0.144446
# Freq: D, Length: 1000, dtype: float64

# %%
print("\nDate range-2001 year:\n", longer_ts["2001"])
# Out:
# Date range-2001 year:
#  2001-01-01   -0.731157
# 2001-01-02   -0.866356
# 2001-01-03    1.847857
# 2001-01-04    2.350783
# 2001-01-05   -0.215778
#                 ...
# 2001-12-27    2.085821
# 2001-12-28   -1.555889
# 2001-12-29   -1.096901
# 2001-12-30   -0.227807
# 2001-12-31   -0.004587
# Freq: D, Length: 365, dtype: float64

# %%
print("\nDate range-05 month 2001 year:\n", longer_ts["2001-05"])
# Out:
# Date range-05 month 2001 year:
#  2001-05-01   -2.813272
# 2001-05-02    0.783587
# 2001-05-03    1.362706
# 2001-05-04    0.869526
# 2001-05-05    1.895044
# 2001-05-06   -2.004793
# 2001-05-07   -1.603198
# 2001-05-08   -0.963625
# 2001-05-09    1.811045
# 2001-05-10   -0.386541
# 2001-05-11   -0.204769
# 2001-05-12    0.656779
# 2001-05-13    1.265718
# 2001-05-14   -1.650037
# 2001-05-15    0.443383
# 2001-05-16    2.660095
# 2001-05-17   -0.164491
# 2001-05-18   -1.315901
# 2001-05-19   -0.868370
# 2001-05-20   -0.048403
# 2001-05-21    0.333388
# 2001-05-22    0.135827
# 2001-05-23   -0.511987
# 2001-05-24   -0.738063
# 2001-05-25   -0.112501
# 2001-05-26    0.234548
# 2001-05-27   -0.241275
# 2001-05-28    0.965429
# 2001-05-29    0.145618
# 2001-05-30    0.387205
# 2001-05-31   -0.558708
# Freq: D, dtype: float64

# %%
print("\nDate range-first few dates in 2000 year:\n",longer_ts["2000"].head())
# Out:
# Date range-first few dates in 2000 year:
#  2000-01-01    0.589928
# 2000-01-02   -0.657529
# 2000-01-03   -0.867016
# 2000-01-04    1.346221
# 2000-01-05    0.003113
# Freq: D, dtype: float64

# %%
print("\nDate range-first 15 dates in 02 month 2001 year:\n",longer_ts["2000-02"].head(15))
# Out:
# Date range-first 15 dates in 02 month 2001 year:
#  2000-02-01   -0.096646
# 2000-02-02    0.507995
# 2000-02-03   -0.072863
# 2000-02-04    1.412813
# 2000-02-05   -2.383820
# 2000-02-06    1.376512
# 2000-02-07    0.516195
# 2000-02-08   -1.270162
# 2000-02-09   -0.761513
# 2000-02-10    0.661881
# 2000-02-11   -0.718956
# 2000-02-12   -0.261537
# 2000-02-13    0.323724
# 2000-02-14   -0.427747
# 2000-02-15   -0.647146
# Freq: D, dtype: float64

# %%
print("\nDate range-rom 26-9-2001:\n",longer_ts[datetime(2000,9,26):])
# Out:
# Date range-rom 26-9-2001:
#  2000-09-26   -1.626429
# 2000-09-27    0.554361
# 2000-09-28   -0.270721
# 2000-09-29   -1.230305
# 2000-09-30   -1.027229
#                 ...
# 2002-09-22   -2.013063
# 2002-09-23    0.833201
# 2002-09-24    0.966244
# 2002-09-25    0.394445
# 2002-09-26   -0.144446
# Freq: D, Length: 731, dtype: float64
