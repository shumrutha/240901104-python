# %% [markdown]
# <a href="https://colab.research.google.com/github/shumrutha/240901104-python/blob/main/numpy2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr=np.array([[-1,2,0,4],[4,-0.5,6,0],[2.6,0,7,8],[3,-7,4,2.0]])
print("Original array:\n",arr)
# Out:
# Original array:
#  [[-1.   2.   0.   4. ]
#  [ 4.  -0.5  6.   0. ]
#  [ 2.6  0.   7.   8. ]
#  [ 3.  -7.   4.   2. ]]

# %%
#returns every other rows
print("\n Every other rows:\n",arr[0:3:2])
# Out:
#  Every other rows:
#  [[-1.   2.   0.   4. ]
#  [ 2.6  0.   7.   8. ]]

# %%
arr=np.array([1,2,3,4,5,6,7])
print("\n original array:",arr)
print("\n original every other element in the array:arr[::2]:",arr[::2])
# Out:
#  original array: [1 2 3 4 5 6 7]
#
#  original every other element in the array:arr[::2]: [1 3 5 7]
